# %% [markdown]
# # <center> **Daily Insights For Covid19 Pandemic** <center>
# #### <center> **(Updated Daily)** <center>

# %% [markdown]
# Coronaviruses are a large family of viruses which may cause illness in animals or humans.  In humans, several coronaviruses are known to cause respiratory infections ranging from the common cold to more severe diseases such as Middle East Respiratory Syndrome (MERS) and Severe Acute Respiratory Syndrome (SARS). The most recently discovered coronavirus causes coronavirus disease COVID-19 [<sup>[1]</sup>](https://www.who.int/news-room/q-a-detail/q-a-coronaviruses)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('BtN-goy9VOY', width=500, height=300)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import gif

# %% [markdown]
# ## **Data**
#
# The Data consist of records of daily confirmed, recovered and death cases from every country and is updated on daily basis. The data repositary is maintained by **Johns Hopkins CSSE** and is available on [GitHub](https://github.com/CSSEGISandData/COVID-19)

# %%
confirmed = pd.read_csv('/home/nabeelhasan/Git/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
confirmed.rename(columns= {"Country/Region" : "Country",
                           "Province/State" : "Province"}, inplace = True)
confirmed.iloc[:, 4:] = confirmed.iloc[:, 4:].fillna(0.0).astype(int)
death = pd.read_csv('/home/nabeelhasan/Git/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
death.rename(columns= {"Country/Region" : "Country",
                           "Province/State" : "Province"}, inplace = True)
death.iloc[:, 4:] = death.iloc[:, 4:].fillna(0.0).astype(int)
recovered = pd.read_csv('/home/nabeelhasan/Git/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
recovered['3/24/20'] = recovered.iloc[:, -1]
recovered.rename(columns= {"Country/Region" : "Country",
                           "Province/State" : "Province"}, inplace = True)
recovered.iloc[:, 4:] = recovered.iloc[:, 4:].fillna(0.0).astype(int)

# %% [markdown]
# ## **Worldwide Cases of Spread**

# %%
covid_19_cases = pd.DataFrame({'Confirmed' :confirmed.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().T.sum(axis = 1),
                               'Death' : death.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().T.sum(axis = 1),
                               'Recovered' :recovered.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().T.sum(axis = 1)})
covid_19_cases.index = pd.to_datetime(covid_19_cases.index).date

# %%
covid_19_cases.tail().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row0_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row1_col0 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row1_col1 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row1_col2 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row2_col0 {
#             background-color:  #fb6b4b;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row2_col1 {
#             background-color:  #fb7353;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row2_col2 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row3_col0 {
#             background-color:  #c7171c;
#             color:  #f1f1f1;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row3_col1 {
#             background-color:  #cc191e;
#             color:  #f1f1f1;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row3_col2 {
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row4_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row4_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_dff84ffa_7233_11ea_b41d_8b4bda80b209row4_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Death</th>        <th class="col_heading level0 col2" >Recovered</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209level0_row0" class="row_heading level0 row0" >2020-03-25</th>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row0_col0" class="data row0 col0" >467653</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row0_col1" class="data row0 col1" >21181</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row0_col2" class="data row0 col2" >113787</td>
#             </tr>
#             <tr>
#                         <th id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209level0_row1" class="row_heading level0 row1" >2020-03-26</th>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row1_col0" class="data row1 col0" >529591</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row1_col1" class="data row1 col1" >23970</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row1_col2" class="data row1 col2" >122150</td>
#             </tr>
#             <tr>
#                         <th id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209level0_row2" class="row_heading level0 row2" >2020-03-27</th>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row2_col0" class="data row2 col0" >593291</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row2_col1" class="data row2 col1" >27198</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row2_col2" class="data row2 col2" >130915</td>
#             </tr>
#             <tr>
#                         <th id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209level0_row3" class="row_heading level0 row3" >2020-03-28</th>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row3_col0" class="data row3 col0" >660706</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row3_col1" class="data row3 col1" >30652</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row3_col2" class="data row3 col2" >139415</td>
#             </tr>
#             <tr>
#                         <th id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209level0_row4" class="row_heading level0 row4" >2020-03-29</th>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row4_col0" class="data row4 col0" >720117</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row4_col1" class="data row4 col1" >33925</td>
#                         <td id="T_dff84ffa_7233_11ea_b41d_8b4bda80b209row4_col2" class="data row4 col2" >149082</td>
#             </tr>
#     </tbody></table>

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize  = (16,8))
    ax1 = plt.subplot2grid(shape = (2,2), loc = (0,1), rowspan = 2, colspan = 1)
    ax1.plot( range(len(covid_19_cases.index)),covid_19_cases['Confirmed'],   linestyle = 'dashed', label = 'Confirmed' )
    ax1.fill_between( range(len(covid_19_cases.index)),covid_19_cases['Confirmed'], color="skyblue", alpha=0.5)
    ax1.tick_params(axis = 'y', labelrotation=45)
    ax1.set_title('Confirmed Cases')
    ax1.set_xlabel('Number of Days')
    ax1.set_ylabel('Confirmed')
    ax2 = plt.subplot2grid(shape = (2,2), loc = (0,0), rowspan = 1, colspan = 1)
    ax2.plot( range(len(covid_19_cases.index)) ,covid_19_cases['Death'], c = 'red', linestyle = 'dashed')
    ax2.fill_between( range(len(covid_19_cases.index)),covid_19_cases['Death'], color="pink", alpha=0.5)
    ax2.tick_params(axis = 'y',labelrotation=45)
    ax2.set_title('Patient Died')
    ax2.set_ylabel('Deaths')
    ax3 = plt.subplot2grid(shape = (2,2), loc = (1,0), rowspan = 1,  colspan = 1)
    ax3.plot( range(len(covid_19_cases.index)) ,covid_19_cases['Recovered'], c = 'green' ,linestyle = 'dashed')
    ax3.fill_between( range(len(covid_19_cases.index)),covid_19_cases['Recovered'], color="lightgreen", alpha=0.5)
    ax3.tick_params(axis = 'y',labelrotation=45)
    ax3.set_title('Recovered Cases')
    ax3.set_xlabel('Number of Days')
    ax3.set_ylabel('Recovered')

# %%
days = []
n = int(covid_19_cases['Confirmed'][-1]/100000) + 1
for i in np.arange (0,n):
    j = 0
    for index in covid_19_cases['Confirmed'].index :
        if covid_19_cases['Confirmed'][index] < i*100000:
            j = j + 1
        else:
            break
    days.append(j)
print('DOTA: Date Of Target Achieved')
print('NOHTC: Next One Hundred Thousand Cases')
print('NODTAT: Number Of Days To Achieve Target')
print('DTANOHT : Days To Achieve Next One Hundred Thousand')
every_10 = pd.DataFrame({'DOTA': covid_19_cases.index[days],
                         'NOHTC': np.arange(0,n)*100000,
                         'NODTAT': days})
every_10['NHTA'] = every_10['NODTAT'].diff().replace(np.nan, 0).astype(int)
every_10
# Out:
# DOTA: Date Of Target Achieved
# NOHTC: Next One Hundred Thousand Cases
# NODTAT: Number Of Days To Achieve Target
# DTANOHT : Days To Achieve Next One Hundred Thousand
#          DOTA   NOHTC  NODTAT  NHTA
# 0  2020-01-22       0       0     0
# 1  2020-03-06  100000      44    44
# 2  2020-03-18  200000      56    12
# 3  2020-03-21  300000      59     3
# 4  2020-03-24  400000      62     3
# 5  2020-03-26  500000      64     2
# 6  2020-03-28  600000      66     2
# 7  2020-03-29  700000      67     1

# %%
plt.figure(figsize = (12,6))
plt.step(every_10['NODTAT'], every_10['NOHTC'], color = 'purple', linestyle = 'dashdot', linewidth = 4.5)
plt.scatter(every_10['NODTAT'], every_10['NOHTC'], color = 'fuchsia', marker = 'o', s = 200)
plt.xlabel('Number of Days')
plt.ylabel('Number of Cases')
plt.savefig('Animated_Objects/dailyMilestone')

# %% [markdown]
# From the data we can see that the number of confirmed cases rose exponentially over the span of sixty days , The number of recovered patients seems to be stable and rising but the number of deaths are skyrocketing for last ten days as this pandemic spread in Western Hemisphere. This shows us how rapidly corona virus spread. Below there is an animation to give the idea of extent of spread in different countries and which countries are hardest hit by Covid19.

# %%
@gif.frame
def plot(a):
    fig = plt.gcf()
    fig.set_size_inches(15, 12)
    m = Basemap(projection='mill', 
            llcrnrlat=-80, urcrnrlat=80, 
            llcrnrlon=-180, urcrnrlon=180, 
            lat_ts=20, 
            resolution='l')
    m.drawcoastlines(color='black', linewidth=0.5)
    m.drawcountries(color='black', linewidth=0.5)
    x, y = m(np.array(confirmed['Long']), np.array(confirmed['Lat']))
    plt.scatter( x,  y,s = (confirmed[f'{a}'])*0.01, c = confirmed[f'{a}'], cmap = 'rainbow', alpha = 0.7, edgecolor = 'grey',linewidth = 1.6)
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title(' Worldwide \n Spread on {}'.format(a), fontsize=14, fontweight='bold')
    
frames = []
for i in confirmed.columns[4:]: 
    frame = plot(i)
    frames.append(frame)

gif.save(frames, "Animated_Objects/worldwide.gif", duration = 250)

# %% [markdown]
# ![Alt Text](Animated_Objects/worldwide.gif)

# %% [markdown]
# ## **Major countries with most number of Covid19 cases**

# %%
major = confirmed.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().iloc[:, -1].sort_values(ascending=False)[0:9]
major = major.to_frame()
major.rename(columns = {major.columns[0]: 'Confirmed'}, inplace = True)
major['Death'] = death.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().loc[(major.index), death.columns[-1]]
major['Recoverd'] = recovered.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().loc[(major.index), recovered.columns[-1]]
major.style.background_gradient(cmap='RdPu')
# Out:
# <style  type="text/css" >
#     #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row0_col0 {
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row0_col1 {
#             background-color:  #fccfcb;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row0_col2 {
#             background-color:  #fef1ed;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row1_col0 {
#             background-color:  #d02690;
#             color:  #f1f1f1;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row1_col1 {
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row1_col2 {
#             background-color:  #fdd7d3;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row2_col0 {
#             background-color:  #f05a9e;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row2_col1 {
#             background-color:  #fbbabd;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row2_col2 {
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row3_col0 {
#             background-color:  #f361a0;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row3_col1 {
#             background-color:  #de3697;
#             color:  #f1f1f1;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row3_col2 {
#             background-color:  #fcd1cd;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row4_col0 {
#             background-color:  #faa0b5;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row4_col1 {
#             background-color:  #fff3f0;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row4_col2 {
#             background-color:  #fde1de;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row5_col0 {
#             background-color:  #fccfcb;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row5_col1 {
#             background-color:  #fcccc7;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row5_col2 {
#             background-color:  #fde6e2;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row6_col0 {
#             background-color:  #fdd3cf;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row6_col1 {
#             background-color:  #fccbc6;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row6_col2 {
#             background-color:  #fdd8d5;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row7_col0 {
#             background-color:  #fef0ec;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row7_col1 {
#             background-color:  #fee7e4;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row7_col2 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row8_col0 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row8_col1 {
#             background-color:  #fff7f3;
#             color:  #000000;
#         }    #T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row8_col2 {
#             background-color:  #fff4f0;
#             color:  #000000;
#         }</style><table id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Death</th>        <th class="col_heading level0 col2" >Recoverd</th>    </tr>    <tr>        <th class="index_name level0" >Country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209level0_row0" class="row_heading level0 row0" >US</th>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row0_col0" class="data row0 col0" >140886</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row0_col1" class="data row0 col1" >2467</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row0_col2" class="data row0 col2" >2665</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209level0_row1" class="row_heading level0 row1" >Italy</th>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row1_col0" class="data row1 col0" >97689</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row1_col1" class="data row1 col1" >10779</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row1_col2" class="data row1 col2" >13030</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209level0_row2" class="row_heading level0 row2" >China</th>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row2_col0" class="data row2 col0" >82122</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row2_col1" class="data row2 col1" >3304</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row2_col2" class="data row2 col2" >75582</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209level0_row3" class="row_heading level0 row3" >Spain</th>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row3_col0" class="data row3 col0" >80110</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row3_col1" class="data row3 col1" >6803</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row3_col2" class="data row3 col2" >14709</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209level0_row4" class="row_heading level0 row4" >Germany</th>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row4_col0" class="data row4 col0" >62095</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row4_col1" class="data row4 col1" >533</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row4_col2" class="data row4 col2" >9211</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209level0_row5" class="row_heading level0 row5" >France</th>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row5_col0" class="data row5 col0" >40708</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row5_col1" class="data row5 col1" >2611</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row5_col2" class="data row5 col2" >7226</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209level0_row6" class="row_heading level0 row6" >Iran</th>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row6_col0" class="data row6 col0" >38309</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row6_col1" class="data row6 col1" >2640</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row6_col2" class="data row6 col2" >12391</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209level0_row7" class="row_heading level0 row7" >United Kingdom</th>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row7_col0" class="data row7 col0" >19780</td>
#                         <td id="T_0d2efcd0_7234_11ea_b41d_8b4bda80b209row7_

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize = (15, 6))
    ax1 = plt.subplot2grid(shape = (2,2), loc= (0,0), rowspan = 2, colspan = 1)
    ax1.bar(major['Confirmed'].sort_values(ascending=False).index, major['Confirmed'].sort_values(ascending=False), color = 'purple' )
    ax1.tick_params(axis = 'x', labelrotation=30)
    ax1.set_title('Confirmed Cases')
    ax2 = plt.subplot2grid(shape = (2,2), loc = (0,1), rowspan = 1, colspan = 1)
    ax2.barh( major['Death'].sort_values(ascending=False).index, major['Death'].sort_values(ascending=False), color = 'fuchsia')
    ax2.tick_params(axis = 'y', labelrotation=0)
    ax2.set_title('Deaths')
    ax3 = plt.subplot2grid(shape = (2,2), loc = (1,1), rowspan = 1, colspan = 1)
    ax3.barh(major['Recoverd'].sort_values(ascending=False).index, major['Recoverd'].sort_values(ascending=False), color = 'pink')
    ax3.tick_params(axis = 'y', labelrotation=0)
    ax3.set_title('Recovered')
    plt.tight_layout()

# %% [markdown]
# ## **Trajectory Of Spread in major countries**

# %% [markdown]
# Cases have stablised in **China** and **South Korea**

# %%
df_09 = confirmed.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().loc[major.index].T
with plt.style.context('fivethirtyeight'):
    df_09.plot(subplots = True, layout = (3,3), linestyle = 'dashdot', figsize = (12,8));

# %% [markdown]
# ## **Momentum of spread (based on rolling mean)**

# %% [markdown]
# **This figure shows the number of cases grow based on five day rolling mean** This give us the current strenght of spread.
# 1. We can see cases in China and Korea have very low momentum now
# 2. Italyand Iran momentum is growing weak and now under 10 percent
# 3. European countries except of Italy have still high spread rate specially in Spain
# 4. United States currently have very high momentum of spread as test show new cases every day

# %%
with plt.style.context('fivethirtyeight'):
    df_09.pct_change().replace(np.inf, np.nan).dropna().rolling(5).mean().plot(subplots = True,
                                                                               layout = (3,3), marker = 'o', alpha = 0.7, figsize = (15,10));

# %% [markdown]
# ## **Rate of Mortality (based on rolling mean)**

# %%
death_df_09 = death.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().loc[major.index].T
with plt.style.context('fivethirtyeight'):
    death_df_09.pct_change().replace(np.inf, np.nan).dropna().rolling(5).mean().plot(subplots = True,
                                                                               layout = (3,3), marker = 'o',alpha = 0.7, figsize = (15,10));

# %% [markdown]
# ## **A Model for Spread of Covid19**

# %% [markdown]
# This is a great explaination by **Grant Sanderson** from [3blue1brown](https://www.youtube.com/channel/UCYO_jab_esuFRV4b17AJtAw). He is certainly a math genius and have an amazing capability of visualizing mathematical concepts

# %%
YouTubeVideo('Kas0tIxDvrg', width=500, height=300)

# %% [markdown]
# ## **Analysis of Covid19 cases in China**

# %%
China = confirmed[confirmed['Country'] == 'China']
China = China.set_index('Province')

# %%
@gif.frame
def plot(a):
    fig = plt.gcf()
    fig.set_size_inches(15, 12)
    m = Basemap(projection='mill', 
            llcrnrlat=15, urcrnrlat=55, 
            llcrnrlon=70, urcrnrlon=135, 
            lat_ts=20, 
            resolution='l')
    m.drawcoastlines(color='black', linewidth=0.5)
    m.drawcountries(color='black', linewidth=0.5)
    x, y = m(np.array(China['Long']), np.array(China['Lat']))
    plt.scatter( x,  y,s = (China[f'{a}'])*0.10, c = China[f'{a}'], cmap = 'rainbow', alpha = 0.7, edgecolor = 'grey',linewidth = 1.6)
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('China \n Spread on {}'.format(a), fontsize=14, fontweight='bold')
    
frames = []
for i in confirmed.columns[4:]: 
    frame = plot(i)
    frames.append(frame)

gif.save(frames, "Animated_Objects/china.gif", duration = 250)

# %% [markdown]
# ![Alt Text](Animated_Objects/china.gif)

# %% [markdown]
# ### **Provincial Data from China**
#
# As **Grant Sanderson** explained in his video once virus started to reach the true population we will observe a Logistic curve. Right now the Chinese government effort of complete lockdown have helped this effort to reach this level very quickly. But this should be taken with sound of caution as China reopens it cities this might spread again. So containment efforts should remain in place as long as we don't see any rapid imporovements in the situation

# %%
with plt.style.context('fivethirtyeight'):
    China.drop(columns = ['Country', 'Lat', 'Long']).T.plot(subplots = True, 
                                                            layout = (11,3), linestyle = (0, (3,1,1,1)), figsize = (15,28));
