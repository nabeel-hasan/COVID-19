# %% [markdown]
# # <center> **Daily Insights For Covid19 Pandemic** <center>
# #### <center> **(Updated Daily)** <center>

# %% [markdown]
# Coronaviruses are a large family of viruses which may cause illness in animals or humans.  In humans, several coronaviruses are known to cause respiratory infections ranging from the common cold to more severe diseases such as Middle East Respiratory Syndrome (MERS) and Severe Acute Respiratory Syndrome (SARS). The most recently discovered coronavirus causes coronavirus disease COVID-19 [<sup>[1]</sup>](https://www.who.int/news-room/q-a-detail/q-a-coronaviruses)

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('BtN-goy9VOY', width=500, height=300)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import gif

# %% [markdown]
# ## **Data**
#
# The Data consist of records of daily confirmed, recovered and death cases from every country and is updated on daily basis. The data repositary is maintained by **Johns Hopkins CSSE** and is available on [GitHub](https://github.com/CSSEGISandData/COVID-19)

# %%
confirmed = pd.read_csv('/home/nabeelhasan/Git/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv')
confirmed.rename(columns= {"Country/Region" : "Country",
                           "Province/State" : "Province"}, inplace = True)
death = pd.read_csv('/home/nabeelhasan/Git/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv')
death.rename(columns= {"Country/Region" : "Country",
                           "Province/State" : "Province"}, inplace = True)
recovered = pd.read_csv('/home/nabeelhasan/Git/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv')
recovered.rename(columns= {"Country/Region" : "Country",
                           "Province/State" : "Province"}, inplace = True)

# %% [markdown]
# ## **Worldwide Cases of Spread**

# %%
covid_19_cases = pd.DataFrame({'Confirmed' :confirmed.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().T.sum(axis = 1),
                               'Death' : death.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().T.sum(axis = 1),
                               'Recovered' :recovered.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().T.sum(axis = 1)})
covid_19_cases.index = pd.to_datetime(covid_19_cases.index)

# %%
covid_19_cases.tail().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow0_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow1_col0 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow1_col1 {
#             background-color:  #fcab8f;
#             color:  #000000;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow1_col2 {
#             background-color:  #fdd1be;
#             color:  #000000;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow2_col0 {
#             background-color:  #e43027;
#             color:  #f1f1f1;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow2_col1 {
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow2_col2 {
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow3_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow3_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow3_col2 {
#             background-color:  #7c0510;
#             color:  #f1f1f1;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow4_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow4_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow4_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Death</th>        <th class="col_heading level0 col2" >Recovered</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225alevel0_row0" class="row_heading level0 row0" >2020-03-19 00:00:00</th>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow0_col0" class="data row0 col0" >242708.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow0_col1" class="data row0 col1" >9867.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow0_col2" class="data row0 col2" >84854.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225alevel0_row1" class="row_heading level0 row1" >2020-03-20 00:00:00</th>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow1_col0" class="data row1 col0" >272166.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow1_col1" class="data row1 col1" >11299.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow1_col2" class="data row1 col2" >87256.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225alevel0_row2" class="row_heading level0 row2" >2020-03-21 00:00:00</th>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow2_col0" class="data row2 col0" >304524.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow2_col1" class="data row2 col1" >12973.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow2_col2" class="data row2 col2" >91499.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225alevel0_row3" class="row_heading level0 row3" >2020-03-22 00:00:00</th>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow3_col0" class="data row3 col0" >335955.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow3_col1" class="data row3 col1" >14632.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow3_col2" class="data row3 col2" >97704.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225alevel0_row4" class="row_heading level0 row4" >2020-03-23 00:00:00</th>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow4_col0" class="data row4 col0" >336004.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow4_col1" class="data row4 col1" >14643.000000</td>
#                         <td id="T_b6846fc6_6d7b_11ea_b0e5_ab93d42e225arow4_col2" class="data row4 col2" >98334.000000</td>
#             </tr>
#     </tbody></table>

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize  = (16,8))
    ax1 = plt.subplot2grid(shape = (2,2), loc = (0,1), rowspan = 2, colspan = 1)
    ax1.plot( range(len(covid_19_cases.index)),covid_19_cases['Confirmed'],   linestyle = 'dashed', label = 'Confirmed' )
    ax1.fill_between( range(len(covid_19_cases.index)),covid_19_cases['Confirmed'], color="skyblue", alpha=0.5)
    ax1.tick_params(axis = 'y', labelrotation=45)
    ax1.set_title('Confirmed Cases')
    ax1.set_xlabel('Number of Days')
    ax1.set_ylabel('Confirmed')
    ax2 = plt.subplot2grid(shape = (2,2), loc = (0,0), rowspan = 1, colspan = 1)
    ax2.plot( range(len(covid_19_cases.index)) ,covid_19_cases['Death'], c = 'red', linestyle = 'dashed')
    ax2.fill_between( range(len(covid_19_cases.index)),covid_19_cases['Death'], color="pink", alpha=0.5)
    ax2.tick_params(axis = 'y',labelrotation=45)
    ax2.set_title('Patient Died')
    ax2.set_ylabel('Deaths')
    ax3 = plt.subplot2grid(shape = (2,2), loc = (1,0), rowspan = 1,  colspan = 1)
    ax3.plot( range(len(covid_19_cases.index)) ,covid_19_cases['Recovered'], c = 'green' ,linestyle = 'dashed')
    ax3.fill_between( range(len(covid_19_cases.index)),covid_19_cases['Recovered'], color="lightgreen", alpha=0.5)
    ax3.tick_params(axis = 'y',labelrotation=45)
    ax3.set_title('Recovered Cases')
    ax3.set_xlabel('Number of Days')
    ax3.set_ylabel('Recovered')

# %% [markdown]
# From the data we can see that the number of confirmed cases rose exponentially over the span of sixty days , The number of recovered patients seems to be stable and rising but the number of deaths are skyrocketing for last ten days as this pandemic spread in Western Hemisphere. This shows us how rapidly corona virus spread. Below there is an animation to give the idea of extent of spread in different countries and which countries are hardest hit by Covid19.

# %%
@gif.frame
def plot(a):
    fig = plt.gcf()
    fig.set_size_inches(15, 12)
    m = Basemap(projection='mill', 
            llcrnrlat=-80, urcrnrlat=80, 
            llcrnrlon=-180, urcrnrlon=180, 
            lat_ts=20, 
            resolution='l')
    m.drawcoastlines(color='black', linewidth=0.5)
    m.drawcountries(color='black', linewidth=0.5)
    x, y = m(np.array(confirmed['Long']), np.array(confirmed['Lat']))
    plt.scatter( x,  y,s = (confirmed[f'{a}'])*0.05, c = confirmed[f'{a}'], cmap = 'rainbow', alpha = 0.7, edgecolor = 'grey',linewidth = 1.6)
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title(' Worldwide \n Spread on {}'.format(a), fontsize=14, fontweight='bold')
    
frames = []
for i in confirmed.columns[4:]: 
    frame = plot(i)
    frames.append(frame)

gif.save(frames, "Animated_Objects/worldwide.gif", duration = 250)

# %% [markdown]
# ![Alt Text](Animated_Objects/worldwide.gif)

# %% [markdown]
# ## **Major countries with most number of Covid19 cases**

# %%
major = confirmed.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().iloc[:, -1].sort_values(ascending=False)[0:9]
major = major.to_frame()
major.rename(columns = {major.columns[0]: 'Confirmed'}, inplace = True)
major['Death'] = death.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().loc[(major.index), death.columns[-1]]
major['Recoverd'] = recovered.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().loc[(major.index), recovered.columns[-1]]
major.style.background_gradient(cmap='cool')
# Out:
# <style  type="text/css" >
#     #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow0_col0 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow0_col1 {
#             background-color:  #9768ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow0_col2 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow1_col0 {
#             background-color:  #b34cff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow1_col1 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow1_col2 {
#             background-color:  #18e7ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow2_col0 {
#             background-color:  #59a6ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow2_col1 {
#             background-color:  #0ff0ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow2_col2 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow3_col0 {
#             background-color:  #4ab5ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow3_col1 {
#             background-color:  #4fb0ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow3_col2 {
#             background-color:  #08f7ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow4_col0 {
#             background-color:  #3cc3ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow4_col1 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow4_col2 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow5_col0 {
#             background-color:  #31ceff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow5_col1 {
#             background-color:  #4bb4ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow5_col2 {
#             background-color:  #1be4ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow6_col0 {
#             background-color:  #1ee1ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow6_col1 {
#             background-color:  #1be4ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow6_col2 {
#             background-color:  #07f8ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow7_col0 {
#             background-color:  #05faff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow7_col1 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow7_col2 {
#             background-color:  #09f6ff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow8_col0 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow8_col1 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }    #T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow8_col2 {
#             background-color:  #00ffff;
#             color:  #000000;
#         }</style><table id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Death</th>        <th class="col_heading level0 col2" >Recoverd</th>    </tr>    <tr>        <th class="index_name level0" >Country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225alevel0_row0" class="row_heading level0 row0" >China</th>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow0_col0" class="data row0 col0" >81439.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow0_col1" class="data row0 col1" >3274.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow0_col2" class="data row0 col2" >72814.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225alevel0_row1" class="row_heading level0 row1" >Italy</th>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow1_col0" class="data row1 col0" >59138.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow1_col1" class="data row1 col1" >5476.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow1_col2" class="data row1 col2" >7024.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225alevel0_row2" class="row_heading level0 row2" >US</th>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow2_col0" class="data row2 col0" >33276.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow2_col1" class="data row2 col1" >417.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow2_col2" class="data row2 col2" >178.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225alevel0_row3" class="row_heading level0 row3" >Spain</th>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow3_col0" class="data row3 col0" >28768.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow3_col1" class="data row3 col1" >1772.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow3_col2" class="data row3 col2" >2575.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225alevel0_row4" class="row_heading level0 row4" >Germany</th>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow4_col0" class="data row4 col0" >24873.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow4_col1" class="data row4 col1" >94.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow4_col2" class="data row4 col2" >266.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225alevel0_row5" class="row_heading level0 row5" >Iran</th>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow5_col0" class="data row5 col0" >21638.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow5_col1" class="data row5 col1" >1685.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow5_col2" class="data row5 col2" >7931.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225alevel0_row6" class="row_heading level0 row6" >France</th>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow6_col0" class="data row6 col0" >16044.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow6_col1" class="data row6 col1" >674.000000</td>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225arow6_col2" class="data row6 col2" >2200.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_e8cb2196_6d7b_11ea_b0e5_ab93d42e225alevel0_row7" class="row_heading level0 row7" >Korea, South</th>
#                         <td id="T_e8cb2196_6d7b_11ea_b0e

# %%
fig = plt.figure(figsize = (12, 6))
ax1 = plt.subplot2grid(shape = (2,2), loc= (0,0), rowspan = 2, colspan = 1)
ax1.bar(major.index, major['Confirmed'], color = 'springgreen' )
ax1.tick_params(axis = 'x', labelrotation=25)
ax1.set_title('Confirmed Cases')
ax2 = plt.subplot2grid(shape = (2,2), loc = (0,1), rowspan = 1, colspan = 1)
ax2.barh( major.index, major['Death'], color = 'aqua')
ax2.tick_params(axis = 'y', labelrotation=0)
ax2.set_title('Deaths')
ax3 = plt.subplot2grid(shape = (2,2), loc = (1,1), rowspan = 1, colspan = 1)
ax3.barh(major.index, major['Recoverd'], color = 'dodgerblue')
ax3.tick_params(axis = 'y', labelrotation=0)
ax3.set_title('Recovred')
plt.tight_layout()

# %% [markdown]
# ## **Trajectory Of Spread in major countries**

# %% [markdown]
# Cases have stablised in **China** and **South Korea**

# %%
df_09 = confirmed.drop(columns = ['Province', 'Lat', 'Long']).groupby('Country').sum().loc[major.index].T
with plt.style.context('fivethirtyeight'):
    df_09.plot(subplots = True, layout = (3,3), linestyle = 'dashdot', figsize = (12,8));

# %% [markdown]
# ## **Momentum of spread (based on rolling mean)**

# %% [markdown]
# **This figure shows the number of cases grow based on five day rolling mean** This give us the current strenght of spread.
# 1. We can see cases in China and Korea have very low momentum now
# 2. Italy's momentum is growing weak but still quit high
# 3. Iran also show downward trend but still have very high momentum of spread
# 4. European countries except of Italy have still high spread rate.
# 5. United States currently have very high momentum of spread as test show new cases every day

# %%
with plt.style.context('fivethirtyeight'):
    df_09.pct_change().replace(np.inf, np.nan).dropna().rolling(5).mean().plot(subplots = True,
                                                                               layout = (3,3), marker = 'o', alpha = 0.7, figsize = (15,10));

# %% [markdown]
# ## **A Model for Spread of Covid19**

# %% [markdown]
# This is a great explaination by **Grant Sanderson** from [3blue1brown](https://www.youtube.com/channel/UCYO_jab_esuFRV4b17AJtAw). He is certainly a math genius and have an amazing capability of visualizing mathematical concepts

# %%
YouTubeVideo('Kas0tIxDvrg', width=500, height=300)

# %% [markdown]
# ## **Analysis of Covid19 cases in China**

# %%
China = confirmed[confirmed['Country'] == 'China']
China = China.set_index('Province')

# %%
@gif.frame
def plot(a):
    fig = plt.gcf()
    fig.set_size_inches(15, 12)
    m = Basemap(projection='mill', 
            llcrnrlat=15, urcrnrlat=55, 
            llcrnrlon=70, urcrnrlon=135, 
            lat_ts=20, 
            resolution='l')
    m.drawcoastlines(color='black', linewidth=0.5)
    m.drawcountries(color='black', linewidth=0.5)
    x, y = m(np.array(China['Long']), np.array(China['Lat']))
    plt.scatter( x,  y,s = (China[f'{a}'])*0.10, c = China[f'{a}'], cmap = 'rainbow', alpha = 0.7, edgecolor = 'grey',linewidth = 1.6)
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('China \n Spread on {}'.format(a), fontsize=14, fontweight='bold')
    
frames = []
for i in confirmed.columns[4:]: 
    frame = plot(i)
    frames.append(frame)

gif.save(frames, "Animated_Objects/china.gif", duration = 250)

# %% [markdown]
# ![Alt Text](Animated_Objects/china.gif)

# %% [markdown]
# ### **Provincial Data from China**
#
# As **Grant Sanderson** explained in his video once virus started to reach the true population we will observe a Logistic curve. Right now the Chinese government effort of complete lockdown have helped this effort to reach this level very quickly. But this should be taken with sound of caution as China reopens it cities this might spread again. So containment efforts should remain in place as long as we don't see any rapid imporovements in the situation

# %%
with plt.style.context('fivethirtyeight'):
    China.drop(columns = ['Country', 'Lat', 'Long']).T.plot(subplots = True, 
                                                            layout = (11,3), linestyle = (0, (3,1,1,1)), figsize = (15,28));

# %% [markdown]
# ## **Analysis of Covid19 cases in US**

# %%
US = confirmed[confirmed['Country'] == 'US']
US = US.set_index('Province')

# %%
US.drop(columns = ['Country', 'Lat', 'Long']).iloc[0:52, -1].sort_values(ascending =
                                                                         False).to_frame()[0:10].style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow1_col0 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow2_col0 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow3_col0 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow4_col0 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow5_col0 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow6_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow7_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow8_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow9_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >3/23/20</th>    </tr>    <tr>        <th class="index_name level0" >Province</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row0" class="row_heading level0 row0" >New York</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow0_col0" class="data row0 col0" >15793.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row1" class="row_heading level0 row1" >Washington</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow1_col0" class="data row1 col0" >1996.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row2" class="row_heading level0 row2" >New Jersey</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow2_col0" class="data row2 col0" >1914.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row3" class="row_heading level0 row3" >California</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow3_col0" class="data row3 col0" >1642.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row4" class="row_heading level0 row4" >Illinois</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow4_col0" class="data row4 col0" >1049.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row5" class="row_heading level0 row5" >Michigan</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow5_col0" class="data row5 col0" >1037.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row6" class="row_heading level0 row6" >Louisiana</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow6_col0" class="data row6 col0" >837.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row7" class="row_heading level0 row7" >Florida</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow7_col0" class="data row7 col0" >830.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row8" class="row_heading level0 row8" >Massachusetts</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow8_col0" class="data row8 col0" >646.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225alevel0_row9" class="row_heading level0 row9" >Texas</th>
#                         <td id="T_02b41bc6_6d7c_11ea_b0e5_ab93d42e225arow9_col0" class="data row9 col0" >627.000000</td>
#             </tr>
#     </tbody></table>

# %%
@gif.frame
def plot(a):
    fig = plt.gcf()
    fig.set_size_inches(15, 12)
    m = Basemap(projection='mill', 
            llcrnrlat=22, urcrnrlat=51, 
            llcrnrlon=-130, urcrnrlon=-65, 
            lat_ts=20, 
            resolution='l')
    m.drawcoastlines(color='black', linewidth=0.5)
    m.drawcountries(color='black', linewidth=0.5)
    x, y = m(np.array(US['Long']), np.array(US['Lat']))
    plt.scatter( x,  y,s = (US[f'{a}']), c = US[f'{a}'], cmap = 'rainbow', alpha = 0.7, edgecolor = 'grey',linewidth = 1.6)
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('US \n Spread on {}'.format(a), fontsize=14, fontweight='bold' )
    
frames = []
for i in confirmed.columns[4:]: 
    frame = plot(i)
    frames.append(frame)

gif.save(frames, "Animated_Objects/eusa.gif", duration = 250)

# %% [markdown]
# ![Alt text](Animated_Objects/eusa.gif)

# %% [markdown]
# Since the virus is in early stages of spread we are seeing an exponential increase in numbers of Covid19 patients in US. This number will continue to rise as more test are done to find new cases in the country. Rapid containment efforts are required in US to slow the spread of diseases. Hardest hit areas are
# 1. **New York**
# 2. **Washington**
# 3. **California**

# %%
with plt.style.context('fivethirtyeight'):
    US.drop(columns = ['Country', 'Lat', 'Long']).iloc[0:52, 30:].T.plot(subplots = True, 
                                                            layout = (13,4), linestyle = (0, (3,1,1,1)), figsize = (15,30));

# %%
confirmed.head()
# Out:
#   Province    Country      Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0      NaN   Thailand  15.0000  101.0000        2        3        5        7
# 1      NaN      Japan  36.0000  138.0000        2        1        2        2
# 2      NaN  Singapore   1.2833  103.8333        0        1        3        3
# 3      NaN      Nepal  28.1667   84.2500        0        0        0        1
# 4      NaN   Malaysia   2.5000  112.5000        0        0        0        3
#
#    1/26/20  1/27/20  ...  3/14/20  3/15/20  3/16/20  3/17/20  3/18/20  \
# 0        8        8  ...       82      114      147      177      212
# 1        4        4  ...      773      839      825      878      889
# 2        4        5  ...      212      226      243      266      313
# 3        1        1  ...        1        1        1        1        1
# 4        4        4  ...      238      428      566      673      790
#
#    3/19/20  3/20/20  3/21/20  3/22/20  3/23/20
# 0      272      322      411      599    599.0
# 1      924      963     1007     1086   1086.0
# 2      345      385      432      455    455.0
# 3        1        1        1        2      2.0
# 4      900     1030     1183     1306   1306.0
#
# [5 rows x 66 columns]
